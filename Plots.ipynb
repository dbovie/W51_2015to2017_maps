# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.io import fits
import matplotlib.patches as patches
import pandas as pd
from astropy.visualization import SqrtStretch
from astropy import wcs
# from wcsaxes import WCSAxes <<<<<<<<<
from matplotlib.colors import LogNorm

# %%
image_file ='/orange/adamginsburg/w51/w51-alma-longbaseline/FITS/W51e2_cont_superuniformSC_tclean.image.fits'

# %%
hdu_list = fits.open(image_file)
hdu_list.info()
# Out:
# Filename: /orange/adamginsburg/w51/w51-alma-longbaseline/FITS/W51e2_cont_superuniformSC_tclean.image.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      79   (7056, 7056, 1, 1)   float32

# %%
image_data = hdu_list[0].data

# %%
print(type(image_data))
print(image_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (1, 1, 7056, 7056)

# %%
image_data = np.squeeze(image_data)

# %%
print(image_data.shape)
# Out:
# (7056, 7056)

# %%
header = hdu_list['PRIMARY'].header

# %%
header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                 7056
# NAXIS2  =                 7056
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   6.056207542618E-06
# BMIN    =   3.947261720896E-06
# BPA     =  -4.425876235962E+01
# BTYPE   = 'Intensity'
# OBJECT  = 'w51e2   '
#
# BUNIT   = 'Jy/beam '           /Brightness (pixel) unit
# RADESYS = 'ICRS    '
# LONPOLE =   1.800000000000E+02
# LATPOLE =   1.450961111111E+01
# PC01_01 =   1.000000000000E+00
# PC02_01 =   0.000000000000E+00
# PC03_01 =   0.000000000000E+00
# PC04_01 =   0.000000000000E+00
# PC01_02 =   0.000000000000E+00
# PC02_02 =   1.000000000000E+00
# PC03_02 =   0.000000000000E+00
# PC04_02 =   0.000000000000E+00
# PC01_03 =   0.000000000000E+00
# PC02_03 =   0.000000000000E+00
# PC03_03 =   1.000000000000E+00
# PC04_03 =   0.000000000000E+00
# PC01_04 =   0.000000000000E+00
# PC02_04 =   0.000000000000E+00
# PC03_04 =   0.000000000000E+00
# PC04_04 =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'
# CRVAL1  =   2.909329583333E+02
# CDELT1  =  -8.333333333333E-07
# CRPIX1  =   3.529000000000E+03
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =   1.450961111111E+01
# CDELT2  =   8.333333333333E-07
# CRPIX2  =   3.529000000000E+03
# CUNIT2  = 'deg     '
# CTYPE3  = 'STOKES  '
# CRVAL3  =   1.000000000000E+00
# CDELT3  =   1.000000000000E+00
# CRPIX3  =   1.000000000000E+00
# CUNIT3  = '        '
# CTYPE4  = 'FREQ    '
# CRVAL4  =   2.260920289534E+11
# CDELT4  =   1.831294267505E+10
# CRPIX4  =   1.000000000000E+00
# CUNIT4  = 'Hz      '
# PV2_1   =   0.000000000000E+00
# PV2_2   =   0.000000000000E+00
# RESTFRQ =   2.178400000000E+11 /Rest Frequency (Hz)
# SPECSYS = 'LSRK    '           /Spectral reference frame
# ALTRVAL =  -1.135648202086E+07 /Alternate frequency reference value
# ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel
# VELREF  =                  257 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'ALMA    '
# OBSERVER= 'cgoddi  '
# DATE-OBS= '2015-10-27T23:21:26.520000'
# TIMESYS = 'UTC     '
# OBSRA   =   2.909329583333E+02
# OBSDEC  =   1.450961111111E+01
# OBSGEO-X=   2.225142180269E+06
# OBSGEO-Y=  -5.440307370349E+06
# OBSGEO-Z=  -2.481029851874E+06
# OBJECT  = 'w51e2   '
# TELESCOP= 'ALMA    '
# INSTRUME= 'ALMA    '
# DISTANCE=   0.000000000000E+00
# DATE    = '2017-10-16T11:45:56.931000' /Date FITS file was written
# ORIGIN  = 'CASA Viewer / FITS export'

# %%
hdu_list.close()

# %%
mywcs = wcs.WCS(header)

# %%
# ??????

# fig = plt.figure()
# ax = WCSAxes(fig, [0.1, 0.1, 0.8, 0.8], wcs=mywcs)
# fig.add_axes(ax)  # note that the axes have to be added to the figure
# ax.imshow(image_data, origin='lower')

# %%
NBINS = 1000
histogram = plt.hist(image_data.flat, NBINS)

# %%
# This definitly is not what I want, but LogNorm did something...

plt.imshow(image_data, cmap='gray', interpolation="nearest", norm=LogNorm(),
          origin="lower")
plt.show()

# %%
cropped = image_data[2800:3800, 3000:4000]

# %%
plt.imshow(cropped, cmap='gray', interpolation="nearest",
          origin="lower")
plt.show()

# %%
fig, ax = plt.subplots(figsize=[10, 10])

# make data
Z2 = cropped
extent = (-6.5, 14, -14, 3)

ax.imshow(Z2, cmap='gray', extent=extent, interpolation="nearest",
          origin="lower")

# inset axes....
axins = ax.inset_axes([0.6, 0.6, 0.47, 0.47])
axins.imshow(Z2, cmap='gray', extent=extent, interpolation="nearest",
          origin="lower")
# sub region of the original image
x1, x2, y1, y2 = -1.5, -0.9, -2.5, -1.9
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.set_xticklabels('')
axins.set_yticklabels('')

ax.indicate_inset_zoom(axins)

plt.show()

# %%
fig, ax = plt.subplots(figsize=[8, 8])

# make data
Z2 = cropped
extent = (0, 20, 0, 20)

ax.imshow(Z2, cmap='gray', extent=extent, interpolation="nearest",
          origin="lower")

# inset axes....
axins = ax.inset_axes([0.5, 0.1, 0.47, 0.47])
axins.imshow(Z2, cmap='gray', extent=extent, interpolation="nearest",
          origin="lower")
# sub region of the original image
x1, x2, y1, y2 = 4, 6.5, 12.5, 15
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.set_xticklabels('')
axins.set_yticklabels('')

ax.indicate_inset_zoom(axins)

plt.show()

# %%
image_file2 ='/orange/adamginsburg/w51/ALMA-IMF_W51/W51-IRS2/B3/cleanest/W51-IRS2_B3_uid___A001_X1296_X18f_continuum_merged_12M_robust0_preselfcal.image.tt0.pbcor.fits'

# %%
hdu_list2 = fits.open(image_file2)
hdu_list2.info()
# Out:
# Filename: /orange/adamginsburg/w51/ALMA-IMF_W51/W51-IRS2/B3/cleanest/W51-IRS2_B3_uid___A001_X1296_X18f_continuum_merged_12M_robust0_preselfcal.image.tt0.pbcor.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      76   (3840, 3840, 1, 1)   float32

# %%
image_data2 = hdu_list2[0].data

# %%
print(type(image_data2))
print(image_data2.shape)
# Out:
# <class 'numpy.ndarray'>
# (1, 1, 3840, 3840)

# %%
image_data2 = np.squeeze(image_data2)

# %%
print(image_data2.shape)
# Out:
# (3840, 3840)

# %%
hdu_list2.close()

# %%
plt.imshow(image_data2, cmap='gray', interpolation="nearest",
          origin="lower")
plt.show()

# %%
zoomin = image_data2[1800:2300, 1600:2300]

# %%
plt.imshow(zoomin, cmap='gray', interpolation="nearest", origin="lower")
plt.show()

# %%
image_file3 ='/orange/adamginsburg/w51/w51-alma-longbaseline/FITS/W51n_cont_uniform.image.tt0.pbcor.fits'

# %%
hdu_list3 = fits.open(image_file3)
hdu_list3.info()
# Out:
# Filename: /orange/adamginsburg/w51/w51-alma-longbaseline/FITS/W51n_cont_uniform.image.tt0.pbcor.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      53   (5120, 5120)   float32

# %%
image_data3 = hdu_list3[0].data

# %%
print(type(image_data3))
print(image_data3.shape)
# Out:
# <class 'numpy.ndarray'>
# (5120, 5120)

# %%
image_data3 = np.squeeze(image_data3)

# %%
print(image_data3.shape)
# Out:
# (5120, 5120)

# %%
hdu_list3.close()

# %%
plt.imshow(image_data3, cmap='gray', interpolation="nearest",
          origin="lower")
plt.show()

# %%
zoomin2 = image_data3[2300:2700, 2300:3300]

# %%
stretch = SqrtStretch()
plt.imshow(zoomin2, cmap='gray', interpolation="nearest", origin="lower")
plt.show()

# %%
fig, ax = plt.subplots(figsize=[8, 8])

# make data
Z3 = zoomin
extent = (0, 20, 0, 20)

ax.imshow(Z3, cmap='gray', extent=extent, interpolation="nearest",
          origin="lower")

# inset axes....
axins = ax.inset_axes([0.4, 0.5, .5, 0.47])
axins.imshow(zoomin2, cmap='gray')
# sub region of the original image
x1, x2, y1, y2 = 6, 10, 5.2, 7.3
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.set_xticklabels('')
axins.set_yticklabels('')

ax.indicate_inset_zoom(axins)

plt.show()

# %%
blob1 = image_data3[2300:2700, 2300:2500]
plt.imshow(zoomin2, cmap='gray', interpolation="nearest", origin="lower", norm=LogNorm())
plt.show()
# This honestly looks really cool, but I don't know what im doing

# %%
zoomin4 = image_data2[1900:2200, 1700:2050]
fig, ax = plt.subplots(figsize=[8, 8])
plt.imshow(zoomin4, cmap='gray', interpolation="nearest", origin="lower")
ax.add_patch(
    patches.Rectangle(xy=(130, 30),  # point of origin.
        width=100,
        height=50,
        linewidth=1,
        color='White',
        fill=False))
# ax.grid(False)
# plt.axis([0, 100, 0, 100])
plt.title('W51 North/IRS2')
plt.axes([.3, .55, .5, .2])
plt.imshow(zoomin2, cmap='gray', interpolation="nearest", origin="lower")
plt.xticks(visible=False)
plt.yticks(visible=False)
plt.grid(False)
plt.show()

# %%
image_file4 ='/orange/adamginsburg/w51/2017.1.00293.S/FITS/w51e2_sci.spw0_4_8_12_16.cube.I.manual.image.pbcor.max.fits'

# %%
hdu_list4 = fits.open(image_file4)
hdu_list4.info()
# Out:
# Filename: /orange/adamginsburg/w51/2017.1.00293.S/FITS/w51e2_sci.spw0_4_8_12_16.cube.I.manual.image.pbcor.max.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      43   (14700, 14700)   float32

# %%
image_data4 = hdu_list4[0].data

# %%
print(type(image_data4))
print(image_data4.shape)
# Out:
# <class 'numpy.ndarray'>
# (14700, 14700)

# %%
image_data4 = np.squeeze(image_data4)

# %%
hdu_list4.close()

# %%
# plt.imshow(image_data4, cmap='gray', interpolation="nearest", origin="lower")
# plt.show()

# %%
# zoomin6 = image_data4[3200:4000, 3000:3800]
# zoomin5 = image_data[3200:4000, 3000:3800]
# fig, ax = plt.subplots(figsize=[8, 8])
# plt.imshow(zoomin5, cmap='gray', interpolation="nearest", origin="lower")
# ax.add_patch(
#     patches.Rectangle(xy=(210, 250),  # point of origin.
#         width=100,
#         height=100,
#         linewidth=1,
#         color='White',
#         fill=False))
# # ax.grid(False)
# # plt.axis([0, 100, 0, 100])
# plt.title('W51 E2')
# plt.axes([.3, .55, .5, .2])
# plt.imshow(zoomin6, cmap='gray', interpolation="nearest", origin="lower")
# plt.xticks(visible=False)
# plt.yticks(visible=False)
# plt.grid(False)
# plt.show()
